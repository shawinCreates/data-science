# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
from sklearn.datasets import make_classification

# %%
X, y = make_classification(n_samples=1000, n_features=2, 
                           n_informative=2, n_redundant=0,
                           n_clusters_per_class=1,
                           weights=[0.9, 0.1],  
                           random_state=42)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='coolwarm', alpha=0.6)
plt.title("Original Imbalanced Dataset")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %%
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter

# %%
ru = RandomUnderSampler()
ru_x, ru_y = ru.fit_resample(X, y)

# %%
print(f"Original: {Counter(y)}")
print(f"UnderSampled: {Counter(ru_y)}")
# Out:
# Original: Counter({np.int64(0): 895, np.int64(1): 105})
# Oversampled: Counter({np.int64(0): 105, np.int64(1): 105})

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
ro = RandomOverSampler()
ro_x, ro_y = ro.fit_resample(X, y)

# %%
print(f"Original: {Counter(y)}")
print(f"OverSampled: {Counter(ro_y)}")
# Out:
# Original: Counter({np.int64(0): 895, np.int64(1): 105})
# OverSampled: Counter({np.int64(0): 895, np.int64(1): 895})
