# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv('../dataset/thyroid_cancer_risk_data.csv')
dataset.head()
# Out:
#    Patient_ID  Age  Gender  Country  Ethnicity Family_History  \
# 0           1   66    Male   Russia  Caucasian             No
# 1           2   29    Male  Germany   Hispanic             No
# 2           3   86    Male  Nigeria  Caucasian             No
# 3           4   75  Female    India      Asian             No
# 4           5   35  Female  Germany    African            Yes
#
#   Radiation_Exposure Iodine_Deficiency Smoking Obesity Diabetes  TSH_Level  \
# 0                Yes                No      No      No       No       9.37
# 1                Yes                No      No      No       No       1.83
# 2                 No                No      No      No       No       6.26
# 3                 No                No      No      No       No       4.10
# 4                Yes                No      No      No       No       9.10
#
#    T3_Level  T4_Level  Nodule_Size Thyroid_Cancer_Risk Diagnosis
# 0      1.67      6.16         1.08                 Low    Benign
# 1      1.73     10.54         4.05                 Low    Benign
# 2      2.59     10.57         4.61                 Low    Benign
# 3      2.62     11.04         2.46              Medium    Benign
# 4      2.11     10.71         2.11                High    Benign

# %%
dataset.shape
# Out:
# (212691, 17)

# %%
input_data = dataset.iloc[:, :-2]
output_data = dataset['Thyroid_Cancer_Risk']

# %%
x_train, x_test, y_train, y_test = train_test_split(input_data, output_data, test_size=0.25)

# %%
x_test.shape, y_test.shape
# Out:
# ((53173, 15), (53173,))

# %%
x_train.shape, y_train.shape
# Out:
# ((159518, 15), (159518,))

# %%
x_train
# Out:
#         Patient_ID  Age  Gender      Country       Ethnicity Family_History  \
# 67075        67076   41  Female       Brazil  Middle Eastern            Yes
# 26215        26216   52    Male        China       Caucasian             No
# 129797      129798   17  Female  South Korea       Caucasian             No
# 199593      199594   79    Male       Russia         African             No
# 87847        87848   89    Male       Brazil       Caucasian            Yes
# ...            ...  ...     ...          ...             ...            ...
# 28734        28735   77  Female      Germany        Hispanic             No
# 27472        27473   46  Female        India  Middle Eastern            Yes
# 64346        64347   21  Female       Brazil           Asian            Yes
# 117236      117237   72  Female        India           Asian             No
# 164447      164448   76    Male        China        Hispanic            Yes
#
#        Radiation_Exposure Iodine_Deficiency Smoking Obesity Diabetes  \
# 67075                  No               Yes      No     Yes       No
# 26215                  No               Yes      No      No       No
# 129797                 No                No      No     Yes       No
# 199593                 No                No      No      No      Yes
# 87847                  No                No      No      No      Yes
# ...                   ...               ...     ...     ...      ...
# 28734                  No                No      No      No       No
# 27472                  No                No     Yes      No      Yes
# 64346                 Yes               Yes      No     Yes       No
# 117236                 No               Yes      No      No       No
# 164447                 No               Yes      No     Yes       No
#
#         TSH_Level  T3_Level  T4_Level  Nodule_Size
# 67075        4.35      0.68      6.57         4.34
# 26215        9.09      0.54      7.50         3.88
# 129797       5.13      1.94     10.82         4.48
# 199593       6.93      1.37      6.06         1.37
# 87847        2.46      2.84      7.92         4.53
# ...           ...       ...       ...          ...
# 28734        0.48      0.91      8.11         0.06
# 27472        4.66      2.09      5.75         4.49
# 64346        4.17      3.06     10.30         3.68
# 117236       5.71      3.04     10.80         3.97
# 164447       3.58      2.16     11.79         1.21
#
# [159518 rows x 15 columns]
