# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../dataset/linear_regression_practice.csv')
df.head()
# Out:
#    Study_Hours  Sleep_Hours  Attendance_%  Exam_Score
# 0         5.99         5.58         91.79       82.89
# 1         4.72         6.58         92.80       80.38
# 2         6.30         6.66         95.42       96.24
# 3         8.05         6.20         95.27      100.00
# 4         4.53         6.84         83.11       77.79

# %%
sns.pairplot(data=df)
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.heatmap(data=df.corr(), annot=True)
plt.show()

# %%
x = df.iloc[:, :-1]
y = df['Exam_Score']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
lr = LinearRegression()
lr.fit(x, y)
# Out:
# LinearRegression()

# %%
lr.score(x_test, y_test)*100
# Out:
# 85.48376978561922

# %%
lr.coef_
# Out:
# array([4.31377478, 1.50353335, 0.50400365])

# %%
lr.intercept_
# Out:
# np.float64(6.694074828786498)

# %%
lr.predict(x_test)
# Out:
# array([ 77.26359806,  92.35728713,  89.54964985,  78.26724464,
#         68.74613383,  86.12809208,  88.58561807,  83.48445759,
#         78.68582621,  87.1857966 ,  76.78623946,  74.80139065,
#         98.186527  ,  74.06641665,  83.76687381,  78.40738579,
#         85.4003911 ,  82.22785795,  88.71293169, 100.75854838,
#         89.884434  ,  79.00301088,  72.89911154,  82.00524269,
#         77.78319328])

# %%
lr.predict([[5,8,100]])
# Out:
# c:\Users\Dell\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([90.69158022])
