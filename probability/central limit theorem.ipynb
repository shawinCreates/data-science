# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
pop_data = [np.random.randint(10,100) for i in range(10000)]
table = pd.DataFrame({"numbers": pop_data})

# %%
np.mean(pop_data)
# Out:
# np.float64(54.6635)

# %%
plt.figure(figsize=(3, 3))
sns.kdeplot(x="numbers", data = table)
plt.show()

# %%
sample_mean = []
for no_sample in range(50):
    sample_data = []
    for data in range(700):
        sample_data.append(np.random.choice(pop_data))
    sample_mean.append(np.mean(sample_data))

# %%
sample_M = pd.DataFrame({"Sample_mean": sample_mean})
plt.figure(figsize=(3, 3))
sns.kdeplot(x="Sample_mean", data=sample_M)
plt.show()

# %%
np.mean(sample_mean)
# Out:
# np.float64(54.511228571428575)

# %%
laptop = pd.read_csv('../dataset/laptop_prices.csv')
laptop.head()
# Out:
#     Brand    Processor  RAM (GB)    Storage                 GPU  \
# 0   Apple  AMD Ryzen 3        64  512GB SSD     Nvidia GTX 1650
# 1   Razer  AMD Ryzen 7         4    1TB SSD     Nvidia RTX 3080
# 2    Asus     Intel i5        32    2TB SSD     Nvidia RTX 3060
# 3  Lenovo     Intel i5         4  256GB SSD     Nvidia RTX 3080
# 4   Razer     Intel i3         4  256GB SSD  AMD Radeon RX 6600
#
#    Screen Size (inch) Resolution  Battery Life (hours)  Weight (kg)  \
# 0                17.3  2560x1440                   8.9         1.42
# 1                14.0   1366x768                   9.4         2.57
# 2                13.3  3840x2160                   8.5         1.74
# 3                13.3   1366x768                  10.5         3.10
# 4                16.0  3840x2160                   5.7         3.38
#
#   Operating System    Price
# 0          FreeDOS  3997.07
# 1            Linux  1355.78
# 2          FreeDOS  2673.07
# 3          Windows   751.17
# ...

# %%
np.mean(laptop['Price'])
# Out:
# np.float64(2183.57160774983)

# %%
plt.figure(figsize=(3, 3))
sns.kdeplot(x="Price", data=laptop)
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
laptop_sample = []
for no_sample in range(80):
    laptop_sample_data =[]
    for sample_data in range(1100):
        laptop_sample_data.append(np.random.choice(laptop['Price']))
    laptop_sample.append(np.mean(laptop_sample_data))

# %%
laptop_sample_data = pd.DataFrame({'laptop_price' : laptop_sample})
plt.figure(figsize=(3,3))
sns.kdeplot(x="laptop_price", data=laptop_sample_data)
# Out:
# <Axes: xlabel='laptop_price', ylabel='Density'>

# %%
np.mean(laptop_sample)
# Out:
# np.float64(2178.465416363636)
